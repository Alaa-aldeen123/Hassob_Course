# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.barplot(x = 'sex', y = 'survived', data = df)
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.barplot(x = 'sex', y = 'survived', data = df, color='lightgreen')
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.barplot(x = 'sex', y = 'survived', data = df, color=['lightgreen','darkgreen'], errorbar= None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 sns.barplot(x = 'sex', y = 'survived', data = df, color=['lightgreen','darkgreen'], errorbar= None)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2371, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2369 saturation = saturation if fill else 1
#    2370 p.map_hue(palette=palette, order=hue_order, norm=hue_norm, saturation=saturation)
# -> 2371 color = _default_color(ax.bar, hue, color, kwargs, saturation=saturation)
#    2373 agg_cls = WeightedAggregator if "weight" in p.plot_data else EstimateAggregator
# ...

# %%
sns.barplot(x = 'sex', y = 'survived', data = df, palette=['lightgreen','darkgreen'], errorbar= None)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6152\2687694079.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = 'sex', y = 'survived', data = df, palette=['lightgreen','darkgreen'], errorbar= None)
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.barplot(x = 'sex', y = 'survived', data = df, palette=['lightgreen','darkgreen'],hue = 'sex', errorbar= None)
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.barplot(x = 'sex', y = 'survived', data = df, palette=['lightgreen','darkgreen'],hue = 'sex', legend = None, errorbar= None)
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.barplot(x = 'sex', y = 'survived', data = df, palette='hls',hue = 'sex', legend = None, errorbar= None)
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.barplot(y = 'sex', x = 'survived', data = df, palette='hls',hue = 'sex', legend = None, errorbar= None)
# Out:
# <Axes: xlabel='survived', ylabel='sex'>

# %%
sns.barplot(x = 'class', y = 'survived', data = df, palette='hls',hue = 'embark_town', errorbar= None)
# Out:
# <Axes: xlabel='class', ylabel='survived'>

# %%
sns.barplot(x = 'class', y = 'survived',hue = 'embark_town',order=['Third', 'Second', 'First'] ,data = df)
# Out:
# <Axes: xlabel='class', ylabel='survived'>
