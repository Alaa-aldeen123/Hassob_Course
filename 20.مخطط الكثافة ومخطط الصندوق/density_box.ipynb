# %%
import pandas as pd

df = pd.read_csv('Students_exams.csv')
df.head()
# Out:
#    gender  math score  reading score  writing score
# 0  female          72             72             74
# 1  female          69             90             88
# 2  female          90             95             93
# 3    male          47             57             44
# 4    male          76             78             75

# %%
df.plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot(kind='density', subplots= True, sharex= True, layout=(2,2))
# Out:
# array([[<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>]], dtype=object)

# %%
df.plot(kind='density', subplots= True, sharex= True)
# Out:
# array([<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#        <Axes: ylabel='Density'>], dtype=object)

# %%
df.plot(kind='density', subplots= True, sharex= False, layout=(2,2))
# Out:
# array([[<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>]], dtype=object)

# %%
df.plot(kind='density', subplots= True)
# Out:
# array([<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#        <Axes: ylabel='Density'>], dtype=object)

# %%
df.plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
df['math score'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
df['math score'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
df['math score'].plot(kind='box')
# Out:
# <Axes: >

# %%
df.plot(kind='box')
# Out:
# <Axes: >

# %%
df.plot(kind='box', subplots = True)
# Out:
# math score          Axes(0.125,0.11;0.227941x0.77)
# reading score    Axes(0.398529,0.11;0.227941x0.77)
# writing score    Axes(0.672059,0.11;0.227941x0.77)
# dtype: object

# %%
df.plot(kind='box', subplots = True, layout=(2,2))
# Out:
# math score          Axes(0.125,0.53;0.352273x0.35)
# reading score    Axes(0.547727,0.53;0.352273x0.35)
# writing score       Axes(0.125,0.11;0.352273x0.35)
# dtype: object

# %%
df2 = pd.read_csv('Students_exams_error.csv')

# %%
df2.plot(kind='box', subplots = True, layout=(2,2))
# Out:
# math score          Axes(0.125,0.53;0.352273x0.35)
# reading score    Axes(0.547727,0.53;0.352273x0.35)
# writing score       Axes(0.125,0.11;0.352273x0.35)
# dtype: object

# %%
df2.plot(kind='box', subplots = True)
# Out:
# math score          Axes(0.125,0.11;0.227941x0.77)
# reading score    Axes(0.398529,0.11;0.227941x0.77)
# writing score    Axes(0.672059,0.11;0.227941x0.77)
# dtype: object

# %%
df.plot(kind='bar', subplots= True, sharex= False, layout=(2,2))
# Out:
# array([[<Axes: title={'center': 'math score'}>,
#         <Axes: title={'center': 'reading score'}>],
#        [<Axes: title={'center': 'writing score'}>, <Axes: >]],
#       dtype=object)

# %%
df.plot(kind='line', subplots= True, sharex= False, layout=(2,2))
# Out:
# array([[<Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >]], dtype=object)

# %%
df.plot(kind='barh', subplots= True, sharex= False, layout=(2,2))
# Out:
# array([[<Axes: title={'center': 'math score'}>,
#         <Axes: title={'center': 'reading score'}>],
#        [<Axes: title={'center': 'writing score'}>, <Axes: >]],
#       dtype=object)

# %%
df.plot(kind='kde', subplots= True, sharex= False, layout=(2,2))
# Out:
# array([[<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>]], dtype=object)

# %%
df.plot(kind='area', subplots= True, sharex= False, layout=(2,2))
# Out:
# array([[<Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >]], dtype=object)

# %%
df['math score'].plot(kind='pie')
# Out:
# <Axes: ylabel='math score'>
